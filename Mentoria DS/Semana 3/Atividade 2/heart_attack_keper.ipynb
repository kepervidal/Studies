# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('heart_2020_cleaned.csv')
df.shape
# Out:
# (319795, 18)

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
homem_mulher= df['Sex'].value_counts()
homem_mulher.plot(kind = 'pie', figsize =(6,6),autopct ='%.2f')
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
sns.countplot(x= 'Sex', hue= 'HeartDisease', data = df)
#O sexo que teve mais doenca cardiaca é o msaculino
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
origem = df['Race'].value_counts()
origem.plot(kind = 'pie', figsize =(6,6),autopct ='%.2f')

#grande parte são pessoas brancas
# Out:
# <AxesSubplot:ylabel='Race'>

# %%
sns.countplot(x= 'Sex', hue= 'AlcoholDrinking', data = df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
bebida = df.groupby('Sex').size()
bebida
# Out:
# Sex
# Female    167805
# Male      151990
# dtype: int64

# %%
bebida = df.groupby('Sex')['AlcoholDrinking'].value_counts()
sns.countplot(x= 'Sex',hue= 'AlcoholDrinking', data= df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
fig, axes = plt.subplots(figsize=(10,8))
sns.histplot(x= 'AgeCategory', hue= 'HeartDisease', data = df)
# Out:
# <AxesSubplot:xlabel='AgeCategory', ylabel='Count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Sex', hue='AgeCategory', data= df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Sex', hue='Stroke', data= df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.barplot(data=df,x="HeartDisease",y="PhysicalHealth",hue="Smoking")
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='PhysicalHealth'>
